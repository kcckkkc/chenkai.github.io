# %%
import pandas as pd
from rdkit import Chem
from tqdm import tqdm
from rdkit.Chem import Draw 
mol = Chem.MolFromSmiles('C(=O)(C(OC(OC(F)(F)F)(F)F)(F)F)O')
Draw.MolToImage(mol, size=(300,150), kekulize=True)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x150>
